# %% [markdown]
# # The first try with  jupyter notebook

# %% [markdown]
# Its bettre than I expect

# %%
with open('datos.txt', 'r') as f:
    for line in f:
        print(line)
# Out:
# Lorem ipsum dolor sit amet consectetur adipisicing elit. Numquam hic libero modi tempore voluptatum ullam ex optio ipsum omnis. Consequuntur iusto, commodi alias veniam fugiat voluptatum. Hic excepturi fugiat voluptates!

# %% [markdown]
# # NumPy

# %%
import numpy as np
a = np.array([1, 2, 3])  # Create a rank 1 array
print(type(a), a.shape, a[0], a[1], a[2])
a[0] = 5                 # Change an element of the array
print(a)
# Out:
# <class 'numpy.ndarray'> (3,) 1 2 3
# [5 2 3]

# %%
from skimage import io
photo = io.imread('image.jpg')

# %%
lista = [1,3,55,9686]
import pandas as pd
pd.Series(lista,['a', 'd', 'g', 'o'])
# Out:
# a       1
# d       3
# g      55
# o    9686
# dtype: int64

# %%
datos = [10,20,30,40]
series = pd.Series(datos,index=['a','b','c','d'])
print(series)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
datos = {
    'Nombres':['Cristina', 'Joseph', 'Sofia'],
    'Edades':[18, 20, 22],
    'Ciudades':['Madrid', 'Barcelona', 'Valencia']
}

df = pd.DataFrame(datos)
print(df)
# Out:
#     Nombres  Edades   Ciudades
# 0  Cristina      18     Madrid
# 1    Joseph      20  Barcelona
# 2     Sofia      22   Valencia

# %%
csv_data = pd.read_csv('datos.csv')
print(csv_data)
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

plt.plot(x, y)
# Out:
#    Nombre  Edad     Ciudad
# 0    Juan    25     Madrid
# 1     Ana    30  Barcelona
# 2  Carlos    35   Valencia
# 3   Maria    20    Sevilla
# 4   Pablo    40   Zaragoza

# %%
js = pd.read_json('datos.json')
print(js)
print(type(js))
# Out:
#    Nombre     Ciudad  Salario
# 0    Juan     Madrid     1000
# 1     Ana  Barcelona     1000
# 2  Carlos   Valencia     1000
# 3   Maria    Sevilla     1000
# 4   Pablo   Zaragoza     1000
# <class 'pandas.core.frame.DataFrame'>

# %%
print(js.info())
print(js.dtypes)
print(js.describe())
print(js['Salario'].mean())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Nombre   5 non-null      object
#  1   Ciudad   5 non-null      object
#  2   Salario  5 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 160.0+ bytes
# None
# Nombre     object
# Ciudad     object
# Salario     int64
# dtype: object
#        Salario
# count      5.0
# mean    1000.0
# std        0.0
# min     1000.0
# 25%     1000.0
# 50%     1000.0
# 75%     1000.0
# max     1000.0
# 1000.0

# %%
print((js['Nombre']))
# Out:
# 0      Juan
# 1       Ana
# 2    Carlos
# 3     Maria
# 4     Pablo
# Name: Nombre, dtype: object

# %%
print(js['Salario']>100)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Salario, dtype: bool

# %%
print(js.loc[1:2,['Ciudad']])
print(js.iloc[1:2,1:3])
# Out:
#       Ciudad
# 1  Barcelona
# 2   Valencia
#       Ciudad  Salario
# 1  Barcelona     1000

# %%
js_filtrado = js[js['Ciudad'] == 'Barcelona']
print(js_filtrado)
# Out:
#   Nombre     Ciudad  Salario
# 1    Ana  Barcelona     1000

# %%
js_sort = js[js['Salario']>=1000].sort_values(by='Salario', ascending=False)
print(js_sort)
# Out:
#    Nombre     Ciudad  Salario
# 0    Juan     Madrid     1000
# 1     Ana  Barcelona     1000
# 2  Carlos   Valencia     1000
# 3   Maria    Sevilla     1000
# 4   Pablo   Zaragoza     1000

# %%
js['Edad']=js['Edad']-10
print(js)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Valentyn\Documents\Curso\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Edad'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 js['Edad']=js['Edad']-10
#       2 print(js)
#
# ...

# %%
# js['Salario'] = np.repeat(a, repeats=len(df), axis=None)
# js.drop(columns= ['Edad'], inplace=False)
# print(js)

# %%
js.to_json('datos.json')#for impruve changes

# %%
print(js.isnull().sum())
# Out:
# Nombre     0
# Ciudad     0
# Salario    0
# dtype: int64

# %%
js.dropna(inplace=True)
print(js)
# Out:
#    Nombre     Ciudad Salario
# 0    Juan     Madrid       0
# 1     Ana  Barcelona       0
# 2  Carlos   Valencia       0
# 3   Maria    Sevilla       0
# 4   Pablo   Zaragoza       0

# %%
js.dropna(axis=1, inplace=True)
print(js)
# Out:
#    Nombre     Ciudad Salario
# 0    Juan     Madrid    1000
# 1     Ana  Barcelona    1000
# 2  Carlos   Valencia    1000
# 3   Maria    Sevilla    1000
# 4   Pablo   Zaragoza    1000

# %%
js.fillna(value=1, inplace=True)
print(js)
# Out:
#    Nombre     Ciudad Salario
# 0    Juan     Madrid    1000
# 1     Ana  Barcelona    1000
# 2  Carlos   Valencia    1000
# 3   Maria    Sevilla    1000
# 4   Pablo   Zaragoza    1000

# %%
# js['Salario'].fillna(js['Salario'].mean(), inplace=True)

# %%
import matplotlib.pyplot as plt
# Datos
x = [1, 2, 3, 4,]
y = [10, 20, 25, 4]

# %%
# Crear gráfico
plt.plot(x, y, marker='o', linestyle='-', color='b', label="Ventas")# Personalizar
plt.xlabel("Días")
plt.ylabel("Ventas")
plt.title("Ventas Diarias")
plt.legend() # Mostrar leyenda
plt.grid(True) # Agregar cuadrícula
# Mostrar gráfico
plt.show()

# %%
plt.plot(x, y, marker='o', linestyle='-', color='r')
plt.show()

# %%
etiquetas = ["Manzanas", "Bananas", "Cerezas"]
valores = [30, 50, 2]
plt.pie(valores, labels=etiquetas, autopct='%1.1f%%', colors=['red','yellow','pink'])
plt.title("Distribución de Frutas")
plt.show()
salario = ["Septembre","Novembre","Desembre"]
value = [1000,1200,1150]
plt.pie(value, labels=salario, autopct='%1.1f%%', colors =['blue','brown','violet'] )
plt.title("Distribución de Salarios")
plt.show()

# %%
import numpy as np
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x, y, color='blue')
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.title("Gráfico de Dispersión")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(x,y)
plt.show()

# %%
z = np.random.rand(180,10,192)
plt.hist(y,x)
plt.show()

# %%
import numpy as np
datos = np.random.randn(1000) # Genera 1000 valores aleatorios
plt.hist(datos, bins=30, color='green', edgecolor='black')
plt.xlabel("Valores")
plt.ylabel("Frecuencia")
plt.title("Histograma")
plt.show()
